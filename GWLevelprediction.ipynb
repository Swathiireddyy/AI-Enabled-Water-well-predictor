# %%
import pandas as pd
import numpy as np
from sklearn import linear_model

# %%
df=pd.read_csv(r"C:\Users\aksha\Desktop\well predictor\dataset.csv")
df
# Out:
#                State   District      Station Name  Latitude  Longitude  \
# 0     Andhra Pradesh    Krishna     A Konduru-New      16.2       81.1
# 1     Andhra Pradesh     Guntur   A Muppalla-DW14      16.3       80.1
# 2     Andhra Pradesh     Guntur   A Muppalla-DW14      16.3       80.1
# 3     Andhra Pradesh  Anantapur       A Roppam-Pz      14.7       77.6
# 4     Andhra Pradesh   Prakasam       Addanki -Pz      15.8       79.9
# ...              ...        ...               ...       ...        ...
# 3271  Andhra Pradesh     Kadapa  Ayyawaripally-PZ      15.3       79.8
# 3272  Andhra Pradesh     Kadapa  Ayyawaripally-PZ      15.3       79.8
# 3273  Andhra Pradesh     Kadapa  Ayyawaripally-PZ      15.3       79.8
# 3274  Andhra Pradesh     Kadapa  Ayyawaripally-PZ      15.3       79.8
# 3275  Andhra Pradesh     Kadapa  Ayyawaripally-PZ      15.3       79.8
#
#      Site Type        GW        ph    Hardness       Solids  Chloramines  \
# ...

# %%
median_gw=df.GW.median()
median_gw
# Out:
# 9.134166

# %%
df.GW=df.GW.fillna(median_gw)
df
# Out:
#                State   District      Station Name  Latitude  Longitude  \
# 0     Andhra Pradesh    Krishna     A Konduru-New      16.2       81.1
# 1     Andhra Pradesh     Guntur   A Muppalla-DW14      16.3       80.1
# 2     Andhra Pradesh     Guntur   A Muppalla-DW14      16.3       80.1
# 3     Andhra Pradesh  Anantapur       A Roppam-Pz      14.7       77.6
# 4     Andhra Pradesh   Prakasam       Addanki -Pz      15.8       79.9
# ...              ...        ...               ...       ...        ...
# 3271  Andhra Pradesh     Kadapa  Ayyawaripally-PZ      15.3       79.8
# 3272  Andhra Pradesh     Kadapa  Ayyawaripally-PZ      15.3       79.8
# 3273  Andhra Pradesh     Kadapa  Ayyawaripally-PZ      15.3       79.8
# 3274  Andhra Pradesh     Kadapa  Ayyawaripally-PZ      15.3       79.8
# 3275  Andhra Pradesh     Kadapa  Ayyawaripally-PZ      15.3       79.8
#
#      Site Type        GW        ph    Hardness       Solids  Chloramines  \
# ...

# %%
from sklearn.tree import DecisionTreeRegressor
reg=DecisionTreeRegressor()

# %%
X=df[['Latitude','Longitude']]
Y=df['GW']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.1, random_state=42)

# %%
reg.fit(X_train,Y_train)
# Out:
# DecisionTreeRegressor()

# %%
reg.coef_
# Out:
# array([0.68822161, 0.31803746])

# %%
reg.intercept_
# Out:
# -25.915814593231353

# %%
input = np.array([[37,90]])

# %%
reg.predict(input)
# Out:
# C:\Users\aksha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([10.24343141])

# %%
16.1*0.66303827+80.1*0.33352314-26.748022311885656
# Out:
# 10.642097349114344

# %%
Y_pred=reg.predict(X_test)
print(Y_pred)
# Out:
# [ 9.29417282  9.29417282  8.95769112  3.21082512 13.05287454 16.50101845
#  10.76859948 21.63558746 16.50101845 13.05287454 17.78693915  6.8458648
#   9.29417282 17.78693915  6.80872011 10.76859948  6.8458648   6.8458648
#  16.50101845 21.63558746 21.63558746  9.48        6.80872011 16.50101845
#   6.8458648  17.78693915 16.50101845  9.29417282 17.78693915 13.05287454
#  10.76859948  6.8458648   8.95769112  3.21082512 13.05287454 10.76859948
#   6.8458648   3.21082512  8.95769112  2.86109069  6.8458648   6.80872011
#  16.50101845  3.21082512 10.76859948 13.05287454 16.50101845 10.24343141
#   8.95769112  6.8458648   4.96890308 17.78693915  6.80872011  4.96890308
#   3.21082512  3.21082512 17.78693915  3.21082512  6.8458648  16.50101845
#   9.29417282 16.50101845 17.78693915  3.21082512 13.05287454  8.95769112
#  17.78693915  4.96890308  4.96890308  4.96890308  6.80872011  2.86109069
#  16.50101845 10.76859948 10.76859948 16.50101845 16.50101845 17.78693915
# ...

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(Y_test, Y_pred)
print(mse)
# Out:
# 6.477508613295655

# %%
import pickle
with open('GW.pkl','wb') as f:
  pickle.dump(reg,f)
